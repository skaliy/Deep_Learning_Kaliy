# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # ChestX

# %% [markdown]
# Kjørt et script som leser igjennom test_list.txt og flytter bildene inn i train mappen

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
from sklearn.metrics import confusion_matrix

# %%
PATH = "/home/sathiesh/skole_ai/dataset/NIH-chest-xrays/data/"

# %%
sz=112
arch=dn121 #trent opp på ImageNet
bs = 16
ratio=97

# %%
label_csv = f'{PATH}Data_Entry_2017.csv' 
#val_idxs = get_cv_idxs(n, val_pct=0.05) #retunerer som default 20% av dataene

# %%
os.listdir(PATH)
# Out:
# ['models',
#  'tmp',
#  'labels.csv',
#  'train',
#  'Data_Entry_2017.csv',
#  'multi_labels.csv',
#  'Orginal']

# %%
df = pd.read_csv(label_csv)

# %% [markdown]
# # Feature engineering and data cleaning

# %%
df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_000.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImageWidth  \
# 0           58              M            PA                2682
# 1           58              M            PA                2894
# 2           58              M            PA                2500
# 3           81              M            PA                2500
# 4           81              F            PA                2582
#
#    OriginalHeight  OriginalImagePixelSpacingx  OriginalImagePixelSpacingy  \
# 0            2749                       0.143                       0.143
# 1            2729                       0.143                       0.143
# 2            2048                       0.168                       0.168
# 3            2048                       0.171                       0.171
# 4            2991                       0.143                       0.143
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df = df.drop(['Follow-up #','Patient ID', 'Patient Age', 'Patient Gender', 'View Position',
              'OriginalImageWidth', 'OriginalHeight', 'OriginalImagePixelSpacingx', 'OriginalImagePixelSpacingy', 'Unnamed: 11'],axis=1)
df.head()
# Out:
#         Image Index          Finding Labels
# 0  00000001_000.png            Cardiomegaly
# 1  00000001_001.png  Cardiomegaly|Emphysema
# 2  00000001_002.png   Cardiomegaly|Effusion
# 3  00000002_000.png              No Finding
# 4  00000003_000.png                  Hernia

# %%
df_sorted = df.pivot_table(index='Finding Labels', aggfunc=len).sort_values('Image Index', ascending=False) 
df_sorted.head()
# Out:
#                 Image Index
# Finding Labels
# No Finding            60361
# Infiltration           9547
# Atelectasis            4215
# Effusion               3955
# Nodule                 2705

# %%
#29 forskjellige rader med ulike type lungebetennelse 
df_pneumonia = df_sorted[df_sorted.index.str.contains('Pneumonia')]
total_pneumonia = sum(df_pneumonia['Image Index'])
total_pneumonia
# Out:
# 1431

# %%
df['is_pneumonia'] = df['Finding Labels'].str.contains('Pneumonia') #ny kolonne med boolske verdier
df[df['is_pneumonia']].is_pneumonia.size == total_pneumonia #make sure that it is correct
# Out:
# True

# %%
df = df.drop(['Finding Labels'], axis=1)
pneumonia = (df['is_pneumonia'])
df = df.append([df[pneumonia]]*ratio, ignore_index=True)

# %%
df = df.sort_values('Image Index'); #sortere slik at bilder med samme navn ligger under hverandre (fiks for å ikke ha verdi i både trening og validering)

# %%
train_ratio = 0.96
n = len(df)
train_size = int((n * train_ratio))
val_idx = list(range(train_size, n))
len(val_idx)
# Out:
# 10038

# %%
val_idx[0:5] #posisjon i df tabellen
# Out:
# [240889, 240890, 240891, 240892, 240893]

# %%
#Hvis True, så ligger ikke det data fra treningssettet i valideringssettet (TODO_finne en bedre løsning)
df['Image Index'][val_idx[0]-1] != df['Image Index'][val_idx[0]] #siste i treningssettet != første i valideringssettet
# Out:
# True

# %%
cleaned_label_path = f'{PATH}labels.csv'
df.to_csv(cleaned_label_path, index=False) #lagres i en annen dir

# %% [markdown]
# # View data

# %%
def get_data(sz): 
    tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on)
    return ImageClassifierData.from_csv(PATH, 'train', cleaned_label_path, test_name=None,
                                       val_idxs=val_idx, tfms=tfms,bs=bs);
    #return data if sz > 300 else data.resize(340, 'tmp'); TODO brukes denne for å hente bildene raskere

# %%
data = get_data(sz)

# %%
fn = PATH+data.trn_ds.fnames[0]
fn
# Out:
# '/home/sathiesh/skole_ai/dataset/NIH-chest-xrays/data/train/00000001_000.png'

# %%
data.trn_ds.fnames.shape ,data.val_ds.fnames.shape
# Out:
# ((240889,), (10038,))

# %%
img = PIL.Image.open(fn);
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024 at 0x7FD155DD6240>

# %%
img.size
# Out:
# (1024, 1024)

# %%
#size_d = {k: PIL.Image.open(PATH+k).size for k in data.trn_ds.fnames} #størrelsene på alle bildene

# %%
#row_sz, col_sz = list(zip(*size_d.values())) #skjønne hva denne gjør

# %%
#row_sz = np.array(row_sz)
#col_sz = np.array(col_sz)

# %%
#row_sz

# %%
#plt.hist(row_sz)

# %%
data.classes[:2]
# Out:
# ['False', 'True']

# %%
#data = get_data(sz,bs); #fikk feilmelding før om at bildet ikke lå i tmp...

# %% [markdown]
# # Training

# %%
learn = ConvLearner.pretrained(arch, data)#, ps=0.5)

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  14%|█▍        | 2159/15056 [02:54<17:23, 12.35it/s, loss=0.77]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-d81c6bd29d71> in <module>()
# ----> 1 learn.lr_find()
#
# ~/skole_ai/fastai/courses/dl1/fastai/learner.py in lr_find(self, start_lr, end_lr, wds, linear)
#     266         layer_opt = self.get_layer_opt(start_lr, wds)
#     267         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 268         self.fit_gen(self.model, self.data, layer_opt, 1)
#     269         self.load('tmp')
#     270
#
# ~/skole_ai/fastai/courses/dl1/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, **kwargs)
#     170         n_epoch = sum_geom(cycle_len if cycle_len else 1, cycle_mult, n_cycle)
#     171         return fit(model, data, n_epoch, layer_opt.opt, self.crit,
# --> 172             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, **kwargs)
#     173
#     174     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/skole_ai/fastai/courses/dl1/fastai/model.py in fit(model, data, epochs, opt, crit, metrics, callbacks, stepper, **kwargs)
#      94             batch_num += 1
#      95             for cb in callbacks: cb.on_batch_begin()
# ---> 96             loss = stepper.step(V(x),V(y), epoch)
#      97             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#      98             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# ~/skole_ai/fastai/courses/dl1/fastai/model.py in step(self, xs, y, epoch)
#      38     def step(self, xs, y, epoch):
#      39         xtra = []
# ---> 40         output = self.m(*xs)
#      41         if isinstance(output,tuple): output,*xtra = output
#      42         self.opt.zero_grad()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torchvision/models/densenet.py in forward(self, x)
#      86
#      87     def forward(self, x):
# ---> 88         new_features = super(_DenseLayer, self).forward(x)
#      89         if self.drop_rate > 0:
#      90             new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     280     def forward(self, input):
#     281         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 282                         self.padding, self.dilation, self.groups)
#     283
#     284
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      88                 _pair(0), groups, torch.backends.cudnn.benchmark,
#      89                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# ---> 90     return f(input, weight, bias)
#      91
#      92
#
# KeyboardInterrupt:
#  14%|█▍        | 2159/15056 [03:10<18:56, 11.35it/s, loss=0.77]

# %%
learn.sched.plot()

# %%
lr = 1e-4

# %%
learn.fit(lr, 3, cycle_len=1)

# %%
learn.unfreeze()

# %%
#learn.lr_find()
#learn.sched.plot()

# %%
lrs = [lr/9, lr/3,lr];

# %%
learn.fit(lrs, 2, cycle_len=1, cycle_mult=2) #brukte lr i stedet for lrs, så det forverret nettet

# %%
learn.save(f'{sz}')

# %%
sz=224

# %%
learn.set_data(get_data(sz))
learn.freeze() 
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)

# %%
learn.lr_find()

# %%
learn.sched.plot()

# %%
learn.unfreeze()
learn.fit(lrs, 2, cycle_len=1, cycle_mult=2)

# %%
learn.save(f'{sz}')

# %%
sz = 299

# %%
learn.set_data(get_data(sz))
learn.freeze()
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)

# %%
learn.unfreeze()
learn.fit(lrs, 2, cycle_len=1, cycle_mult=2)
learn.save(f'{sz}')

# %% [markdown]
# #  Analyzing the results

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))

# %%
log_preds,y = learn.TTA()
probs = np.mean(np.exp(log_preds),axis=0)

accuracy_np(probs, y)

# %%
probs

# %%
preds = np.argmax(probs, axis=1)  # from log probabilities to 0 or 1 #arg max velger posisjonen til den med høyest verdi. Altså enten posisjon 0 eller 1 i dette tilfelle
probs = probs[:,1]        # pr(pneumonia)

# %%
cm = confusion_matrix(y,preds); #sklearn method

# %%
plot_confusion_matrix(cm,['other', 'pneumonia'])

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect pneumonia")

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Predict pneumothorax vs no finding

# %% [markdown]
# This project started with trying to recreate the ChestXNet project. Briefly explained, the ChestXNet group has developed an algorithm to classify pneumonia from other thoracic diseases in the ChestX-ray14 data set released by Wang et al. (2017). This data set contains of 112,120 frontal-view chest X-ray images, where each of them are labeled with up to 14 different diseases. You can read more about the CheXNet here: https://stanfordmlgroup.github.io/projects/chexnet/
# <br>
#
# Some of the issues I encountered along the way with this paper was that they have not described how they have balanced pneumonia in relation to all other diseases, how they have handled image of the same patient in the training and the validation sets, and how their test set looks like.
# <br>
#
# Therefore, it has been difficult for me to compare this project with theirs.
# The purpose of recreating their project was to use a trained network on chest X ray14 data set to train another x-ray data set and look into the value of transfer learning.
# To achieve a well trained network on chestX-ray 14 data set we have decided to look into another disease with more unique examples in the dataset compared with pneumonia.

# %%
import sys
sys.path.append("../../fastai/")

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
from sklearn.metrics import confusion_matrix

# %%
PATH = "/home/sathiesh/Deep_Learning_Kaliy/my_projects/chest-xrays/data/"  #MMIV
#PATH = "/Users/Sathiesh/MachineLearning/Deep_Learning_Kaliy/my_projects/chest-xrays/data/" #Home

# %%
sz=64
arch=dn121
bs = 16

# %%
label_csv = f'{PATH}Data_Entry_2017.csv'

# %%
os.listdir(PATH)
# Out:
# ['models',
#  'tmp',
#  'labels.csv',
#  'train',
#  'train_contrast',
#  'test',
#  'Data_Entry_2017.csv',
#  'test_list.txt',
#  'cleaned_labels']

# %%
df = pd.read_csv(label_csv)

# %% [markdown]
# # Feature engineering and data cleaning

# %% [markdown]
# Below is a brief information about the required columns from the dataset:
# - ###### Image Index: The name of an image
# - ###### Finding Labels: Shows the disease(s)

# %%
df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_000.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImageWidth  \
# 0           58              M            PA                2682
# 1           58              M            PA                2894
# 2           58              M            PA                2500
# 3           81              M            PA                2500
# 4           81              F            PA                2582
#
#    OriginalHeight  OriginalImagePixelSpacingx  OriginalImagePixelSpacingy  \
# 0            2749                       0.143                       0.143
# 1            2729                       0.143                       0.143
# 2            2048                       0.168                       0.168
# 3            2048                       0.171                       0.171
# 4            2991                       0.143                       0.143
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df = df.drop(['Follow-up #','Patient ID', 'Patient Age', 'Patient Gender', 'View Position',
              'OriginalImageWidth', 'OriginalHeight', 'OriginalImagePixelSpacingx', 'OriginalImagePixelSpacingy', 'Unnamed: 11'],axis=1)
df.head()
# Out:
#         Image Index          Finding Labels
# 0  00000001_000.png            Cardiomegaly
# 1  00000001_001.png  Cardiomegaly|Emphysema
# 2  00000001_002.png   Cardiomegaly|Effusion
# 3  00000002_000.png              No Finding
# 4  00000003_000.png                  Hernia

# %% [markdown]
# ## Top 10 diseases in the dataset

# %%
df_sorted = df.pivot_table(index='Finding Labels', aggfunc=len).sort_values('Image Index', ascending=False) 
df_sorted[0:10].plot(kind='bar',figsize=(13,8))

# %%
df_sorted.head(10)
# Out:
#                           Image Index
# Finding Labels
# No Finding                      60361
# Infiltration                     9547
# Atelectasis                      4215
# Effusion                         3955
# Nodule                           2705
# Pneumothorax                     2194
# Mass                             2139
# Effusion|Infiltration            1603
# Atelectasis|Infiltration         1350
# Consolidation                    1310

# %% [markdown]
# ## Analyzing a specific disease
# If this returns true, then skip to <i> view data</i> section

# %%
disease_name = 'Pneumothorax'
cleaned_label_path = f'{PATH}cleaned_labels/{disease_name}.csv' 
exists = os.path.exists(cleaned_label_path)
if(False): 
    df = pd.read_csv(cleaned_label_path)
print('If exists equals true, then skip to view data section')
print('exists = ' + str(exists))
# Out:
# If exists equals true, then skip to view data section
# exists = True

# %%
df_disease = df_sorted[df_sorted.index.str.contains(disease_name)]
disease_row = df_sorted.loc[disease_name]['Image Index']
total_apperance = sum(df_disease['Image Index'])
print(disease_name +': ' + str(disease_row) + '\n'+ 'Total apperance: ' + str(total_apperance))
# Out:
# Pneumothorax: 2194
# Total apperance: 5302

# %%
df.shape
# Out:
# (112120, 2)

# %% [markdown]
# Remove the rows that are combined with one or more of the other diseases.<br>
# In this way, we have <i>one diease vs all the others</i>.

# %%
df['searching_disease'] = df['Finding Labels'].str.contains(disease_name)
no_finding_idxs =  list(df.loc[df['Finding Labels'] == 'No Finding'].index)
searching_disease_idxs = list(df[df['searching_disease']].index) #all rows with disease_name

# %%
arr = np.concatenate((no_finding_idxs, searching_disease_idxs), axis=0)

# %%
df = df.iloc[df.index.get_indexer(arr)]

# %%
df.head()
# Out:
#          Image Index Finding Labels  searching_disease
# 3   00000002_000.png     No Finding              False
# 13  00000005_000.png     No Finding              False
# 14  00000005_001.png     No Finding              False
# 15  00000005_002.png     No Finding              False
# 16  00000005_003.png     No Finding              False

# %%
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (65663, 3)

# %% [markdown]
# ### Ratio
# Find the ratio to balance the data

# %%
df_sorted = df.pivot_table(index='searching_disease', aggfunc=len).sort_values('Image Index') 
df_sorted.index = [disease_name,'Other']
df_sorted['Image Index'].plot(kind='bar', title="Other diseases vs "+disease_name)

# %%
df_sorted
# Out:
#               Finding Labels  Image Index
# Pneumothorax            5302         5302
# Other                  60361        60361

# %%
disease_count = df_sorted['Image Index'][0]
other_disease_count = df_sorted['Image Index'][1]
ratio = (other_disease_count// disease_count)-1
df = df.append([df[df.searching_disease]]*ratio, ignore_index=True) #df.searching_disease: array m true, false 
ratio
# Out:
# 10

# %%
df_sorted = df.pivot_table(index='searching_disease', aggfunc=len).sort_values('Image Index') 
df_sorted.index = [disease_name,'Other']
df_sorted['Image Index'].plot(kind='bar', title="Other diseases vs "+disease_name)

# %%
df = df.drop(['Finding Labels'], axis=1)

# %%
df.head()
# Out:
#         Image Index  searching_disease
# 0  00000002_000.png              False
# 1  00000005_000.png              False
# 2  00000005_001.png              False
# 3  00000005_002.png              False
# 4  00000005_003.png              False

# %%
cleaned_label_path = f'{PATH}/cleaned_labels/{disease_name}.csv'
df.to_csv(cleaned_label_path, index=False)

# %% [markdown]
# # View data
# The validation set we create with the training set may contain images of the same patient as there are several images of a patient. This may lead to better results on the validation set than on test set.
# Since we want a well trained network on chestX-ray 14 data set to look into the value of transfer learning, we have decided to use the test set as the validation set.

# %% [markdown]
# The indexes of all the images that should be in the validation set

# %%
#val_idxs = df[df['Image Index'].isin(val_image_name_list)].index 
#len(val_idxs)
??ImageClassifierData.from_csv()

# %%
def get_data(sz): 
    tfms = tfms_from_model(arch, sz, aug_tfms=RandomFlip())
    return ImageClassifierData.from_csv(PATH, 'train', cleaned_label_path, test_name="test", tfms=tfms, bs=bs);

# %%
data = get_data(sz)

# %%
fn = PATH+data.trn_ds.fnames[0]
fn
# Out:
# '/home/sathiesh/Deep_Learning_Kaliy/my_projects/chest-xrays/data/train/00000005_000.png'

# %%
data.trn_ds.fnames.shape ,data.val_ds.fnames.shape, len(data.test_ds.fnames)
# Out:
# ((94947,), (23736,), 25596)

# %%
img = PIL.Image.open(fn);
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024 at 0x7FEF973EC6A0>

# %%
img.size

# %%
size_d = {k: PIL.Image.open(PATH+k).size for k in data.trn_ds.fnames} #størrelsene på alle bildene

# %%
row_sz, col_sz = list(zip(*size_d.values())) #skjønne hva denne gjør

# %%
row_sz = np.array(row_sz)
col_sz = np.array(col_sz)

# %%
row_sz

# %%
plt.hist(row_sz)

# %%
data.classes[:2]
# Out:
# ['False', 'True']

# %%
test_image_name_list = [line.rstrip('\n') for line in open(f'{PATH}test_list.txt')]
test_image_name_list[:5]
# Out:
# ['00000003_000.png',
#  '00000003_001.png',
#  '00000003_002.png',
#  '00000003_003.png',
#  '00000003_004.png']

# %%
data.test_ds.fnames
# Out:
# ['test/00030533_000.png',
#  'test/00022611_010.png',
#  'test/00008814_004.png',
#  'test/00023085_006.png',
#  'test/00002437_006.png',
#  'test/00006304_056.png',
#  'test/00001777_002.png',
#  'test/00028180_005.png',
#  'test/00014688_013.png',
#  'test/00007551_005.png',
#  'test/00019769_003.png',
#  'test/00006890_003.png',
#  'test/00013685_040.png',
#  'test/00007120_012.png',
#  'test/00012576_010.png',
#  'test/00011683_057.png',
#  'test/00010677_007.png',
#  'test/00010481_023.png',
#  'test/00030522_002.png',
#  'test/00010828_038.png',
#  'test/00028518_017.png',
#  'test/00007557_016.png',
#  'test/00025707_017.png',
#  'test/00028148_005.png',
#  'test/00003528_051.png',
#  'test/00003528_059.png',
#  'test/00030162_024.png',
#  'test/00010936_026.png',
#  'test/00007728_000.png',
#  'test/00006736_001.png',
#  'test/00030002_000.png',
#  'test/00013192_000.png',
#  'test/00013685_006.png',
#  'test/00016587_048.png',
#  'test/00020819_009.png',
#  'test/00019767_006.png',
#  'test/00027094_002.png',
#  'test/00018865_015.png',
#  'test/00001836_054.png',
#  'test/00001787_000.png',
#  'test/00006304_047.png',
#  'test/00000808_013.png',
#  'test/00002704_019.png',
#  'test/00010575_003.png',
#  'test/00012087_048.png',
#  'test/00023093_009.png',
#  'test/00007551_012.png',
#  'test/00016607_029.png',
#  'test/00009953_034.png',
#  'test/00016508_052.png',
#  'test/00022215_014.png',
#  'test/00012576_021.png',
#  'test/00010012_003.png',
#  'test/00010677_006.png',
#  'test/00001946_009.png',
#  'test/00001373_019.png',
#  'test/00019766_031.png',
#  'test/00027935_001.png',
#  'test/00026911_005.png',
#  'test/00010959_011.png',
#  'test/00020852_003.png',
#  'test/00012386_007.png',
#  'test/00026810_007.png',
#  'test/00001248_002.png',
#  'test/00020408_001.png',
#  'test/00014675_009.png',
#  'test/00018055_037.png',
#  'test/00030680_001.png',
#  'test/00006713_013.png',
#  'test/00005962_013.png',
#  'test/00019767_014.png',
#  'test/00025664_021.png',
#  'test/00015770_031.png',
#  'test/00007886_002.png',
#  'test/00021277_032.png',
#  'test/00004342_057.png',
#  'test/00027685_009.png',
#  'test/00020277_001.png',
#  'test/00005140_009.png',
#  'test/00005962_010.png',
#  'test/00014663_020.png',
#  'test/00013670_159.png',
#  'test/00026338_002.png',
#  'test/00001006_016.png',
#  'test/00012123_001.png',
#  'test/00018657_014.png',
#  'test/00001075_041.png',
#  'test/00002437_019.png',
#  'test/00008008_042.png',
#  'test/00018865_044.png',
#  'test/00021711_005.png',
#  'test/00030636_005.png',
#  'test/00014177_002.png',
#  'test/00011702_051.png',
#  'test/00022815_080.png',
#  'test/00022977_000.png',
#  'test/00003528_028.png',
#  'test/00029103_000.png',
#  'test/00000506_012.png',
#  'test/00010092_025.png',
#  'test/00027357_015.png',
#  'test/00014197_011.png',
#  'test/00018366_027.png',
#  'test/00000003_002.png',
#  'test/00016434_003.png',
#  'test/00004822_026.png',
#  'test/00027652_002.png',
#  'test/00029582_000.png',
#  'test/00014677_002.png',
#  'test/00002704_006.png',
#  'test/00030340_000.png',
#  'test/00011576_002.png',
#  'test/00030323_030.png',
#  'test/00028872_000.png',
#  'test/00023162_026.png',
#  'test/00020482_062.png',
#  'test/00027577_002.png',
#  'test/00000467_005.png',
#  'test/00017611_001.png',
#  'test/00016490_022.png',
#  'test/00016508_031.png',
#  'test/00013625_033.png',
#  'test/00009507_004.png',
#  'test/00011237_014.png',
#  'test/00021009_001.png',
#  'test/00017981_019.png',
#  'test/00020408_047.png',
#  'test/00016014_000.png',
#  'test/00017504_066.png',
#  'test/00012515_010.png',
#  'test/00023116_001.png',
#  'test/00010481_037.png',
#  'test/00004858_055.png',
#  'test/00006808_017.png',
#  'test/00029579_010.png',
#  'test/00008397_001.png',
#  'test/00014996_017.png',
#  'test/00029321_000.png',
#  'test/00016587_033.png',
#  'test/00018253_008.png',
#  'test/00021201_056.png',
#  'test/00026753_011.png',
#  'test/00029884_001.png',
#  'test/00013993_101.png',
#  'test/00010805_044.png',
#  'test/00013111_023.png',
#  'test/00017257_002.png',
#  'test/00001900_000.png',
#  'test/00029736_000.png',
#  'test/00023081_007.png',
#  'test/00030098_000.png',
#  'test/00017504_004.png',
#  'test/00015171_012.png',
#  'test/00016009_004.png',
#  'test/00028774_012.png',
#  'test/00012021_024.png',
#  'test/00009574_005.png',
#  'test/00010007_105.png',
#  'test/00023093_005.png',
#  'test/00006481_009.png',
#  'test/00030323_022.png',
#  'test/00005681_012.png',
#  'test/00019124_018.png',
#  'test/00011832_001.png',
#  'test/00009945_006.png',
#  'test/00027592_013.png',
#  'test/00008522_038.png',
#  'test/00029596_013.png',
#  'test/00023309_014.png',
#  'test/00010871_014.png',
#  'test/00011391_022.png',
#  'test/00006621_000.png',
#  'test/00030079_021.png',
#  'test/00000865_010.png',
#  'test/00017138_092.png',
#  'test/00019363_003.png',
#  'test/00028317_011.png',
#  'test/00023116_014.png',
#  'test/00020603_006.png',
#  'test/00004188_008.png',
#  'test/00021201_074.png',
#  'test/00016587_038.png',
#  'test/00007750_014.png',
#  'test/00022290_000.png',
#  'test/00017500_000.png',
#  'test/00003945_006.png',
#  'test/00004381_002.png',
#  'test/00003028_073.png',
#  'test/00022961_005.png',
#  'test/00018686_000.png',
#  'test/00011857_008.png',
#  'test/00013627_001.png',
#  'test/00026865_001.png',
#  'test/00018233_005.png',
#  'test/00020945_043.png',
#  'test/00028518_014.png',
#  'test/00012048_007.png',
#  'test/00003528_049.png',
#  'test/00004533_005.png',
#  'test/00021374_024.png',
#  'test/00014677_009.png',
#  'test/00012747_006.png',
#  'test/00029631_001.png',
#  'test/00006271_084.png',
#  'test/00015895_007.png',
#  'test/00026392_006.png',
#  'test/00014839_004.png',
#  'test/00027631_007.png',
#  'test/00028840_000.png',
#  'test/00020333_001.png',
#  'test/00003062_007.png',
#  'test/00028619_001.png',
#  'test/00010815_008.png',
#  'test/00021748_003.png',
#  'test/00015732_018.png',
#  'test/00020408_019.png',
#  'test/00015799_027.png',
#  'test/00030237_000.png',
#  'test/00028499_000.png',
#  'test/00006964_000.png',
#  'test/00019861_011.png',
#  'test/00016971_037.png',
#  'test/00014677_000.png',
#  'test/00018253_077.png',
#  'test/00009166_015.png',
#  'test/00001836_014.png',
#  'test/00004533_006.png',
#  'test/00006481_002.png',
#  'test/00019271_003.png',
#  'test/00007498_000.png',
#  'test/00029070_000.png',
#  'test/00027441_009.png',
#  'test/00018427_000.png',
#  'test/00013862_003.png',
#  'test/00009229_005.png',
#  'test/00017747_026.png',
#  'test/00011702_043.png',
#  'test/00026319_002.png',
#  'test/00025252_036.png',
#  'test/00027631_003.png',
#  'test/00029242_000.png',
#  'test/00015646_040.png',
#  'test/00025252_004.png',
#  'test/00021374_006.png',
#  'test/00009138_043.png',
#  'test/00016490_004.png',
#  'test/00023068_025.png',
#  'test/00021972_021.png',
#  'test/00005962_003.png',
#  'test/00025252_020.png',
#  'test/00016175_003.png',
#  'test/00002722_003.png',
#  'test/00000032_052.png',
#  'test/00017236_008.png',
#  'test/00016417_004.png',
#  'test/00011683_039.png',
#  'test/00000583_064.png',
#  'test/00022416_079.png',
#  'test/00005066_002.png',
#  'test/00027441_003.png',
#  'test/00014626_000.png',
#  'test/00007735_028.png',
#  'test/00018387_032.png',
#  'test/00003394_001.png',
#  'test/00004822_025.png',
#  'test/00006912_006.png',
#  'test/00026451_016.png',
#  'test/00003803_000.png',
#  'test/00000467_003.png',
#  'test/00029218_000.png',
#  'test/00017138_088.png',
#  'test/00014004_009.png',
#  'test/00012364_064.png',
#  'test/00020845_002.png',
#  'test/00027726_015.png',
#  'test/00028876_040.png',
#  'test/00012376_005.png',
#  'test/00013209_003.png',
#  'test/00026338_000.png',
#  'test/00014095_004.png',
#  'test/00014688_012.png',
#  'test/00017138_090.png',
#  'test/00014125_036.png',
#  'test/00019373_018.png',
#  'test/00016972_026.png',
#  'test/00012087_002.png',
#  'test/00002856_019.png',
#  'test/00015255_004.png',
#  'test/00021782_015.png',
#  'test/00013471_025.png',
#  'test/00028628_009.png',
#  'test/00007735_043.png',
#  'test/00019208_006.png',
#  'test/00018657_005.png',
#  'test/00014675_032.png',
#  'test/00030358_003.png',
#  'test/00015646_046.png',
#  'test/00030508_000.png',
#  'test/00021972_003.png',
#  'test/00026818_029.png',
#  'test/00002704_000.png',
#  'test/00025954_019.png',
#  'test/00023068_014.png',
#  'test/00017405_034.png',
#  'test/00019363_011.png',
#  'test/00009953_003.png',
#  'test/00025936_000.png',
#  'test/00006134_000.png',
#  'test/00002059_005.png',
#  'test/00019150_018.png',
#  'test/00000849_000.png',
#  'test/00023075_037.png',
#  'test/00010563_023.png',
#  'test/00017318_002.png',
#  'test/00028126_000.png',
#  'test/00022415_003.png',
#  'test/00000661_001.png',
#  'test/00018721_024.png',
#  'test/00012515_005.png',
#  'test/00010828_037.png',
#  'test/00015563_014.png',
#  'test/00006808_001.png',
#  'test/00015843_008.png',
#  'test/00012505_005.png',
#  'test/00002529_026.png',
#  'test/00029842_000.png',
#  'test/00017138_032.png',
#  'test/00027479_003.png',
#  'test/00029861_006.png',
#  'test/00028246_000.png',
#  'test/00019124_051.png',
#  'test/00013112_007.png',
#  'test/00013111_063.png',
#  'test/00001247_004.png',
#  'test/00019919_008.png',
#  'test/00009349_001.png',
#  'test/00000618_006.png',
#  'test/00001152_000.png',
#  'test/00000013_027.png',
#  'test/00010092_047.png',
#  'test/00018705_004.png',
#  'test/00029464_007.png',
#  'test/00017036_005.png',
#  'test/00003394_003.png',
#  'test/00030637_020.png',
#  'test/00013471_010.png',
#  'test/00022572_089.png',
#  'test/00016719_000.png',
#  'test/00026769_003.png',
#  'test/00008554_006.png',
#  'test/00012834_038.png',
#  'test/00027631_001.png',
#  'test/00027093_005.png',
#  'test/00000533_002.png',
#  'test/00013209_002.png',
#  'test/00003945_008.png',
#  'test/00012622_019.png',
#  'test/00021972_009.png',
#  'test/00000032_007.png',
#  'test/00020408_063.png',
#  'test/00010007_018.png',
#  'test/00022192_010.png',
#  'test/00009845_042.png',
#  'test/00017448_005.png',
#  'test/00007018_034.png',
#  'test/00021896_004.png',
#  'test/00003148_012.png',
#  'test/00009218_007.png',
#  'test/00016568_024.png',
#  'test/00017236_004.png',
#  'test/00012829_006.png',
#  'test/00012376_001.png',
#  'test/00026753_002.png',
#  'test/00019313_008.png',
#  'test/00001688_001.png',
#  'test/00022141_019.png',
#  'test/00018721_022.png',
#  'test/00029288_000.png',
#  'test/00017236_026.png',
#  'test/00016587_074.png',
#  'test/00030162_025.png',
#  'test/00029995_000.png',
#  'test/00007668_007.png',
#  'test/00018253_016.png',
#  'test/00018360_016.png',
#  'test/00017524_036.png',
#  'test/00026287_006.png',
#  'test/00004808_096.png',
#  'test/00009892_035.png',
#  'test/00010007_177.png',
#  'test/00019018_011.png',
#  'test/00021321_016.png',
#  'test/00021222_012.png',
#  'test/00027592_000.png',
#  'test/00011583_018.png',
#  'test/00030260_011.png',
#  'test/00016568_040.png',
#  'test/00009349_032.png',
#  'test/00009574_003.png',
#  'test/00013031_032.png',
#  'test/00030596_000.png',
#  'test/00010012_024.png',
#  'test/00010007_120.png',
#  'test/00002665_000.png',
#  'test/00016258_013.png',
#  'test/00003528_053.png',
#  'test/00013922_025.png',
#  'test/00008911_017.png',
#  'test/00006674_006.png',
#  'test/00028873_001.png',
#  'test/00021818_002.png',
#  'test/00023156_011.png',
#  'test/00022707_006.png',
#  'test/00028222_000.png',
#  'test/00021896_001.png',
#  'test/00013128_020.png',
#  'test/00026818_008.png',
#  'test/00020945_018.png',
#  'test/00011391_059.png',
#  'test/00001170_049.png',
#  'test/00018412_006.png',
#  'test/00029200_000.png',
#  'test/00028891_000.png',
#  'test/00007750_007.png',
#  'test/00007322_011.png',
#  'test/00005089_033.png',
#  'test/00028199_000.png',
#  'test/00026451_072.png',
#  'test/00008295_034.png',
#  'test/00009845_045.png',
#  'test/00021782_036.png',
#  'test/00002101_001.png',
#  'test/00000013_042.png',
#  'test/00005532_027.png',
#  'test/00019157_007.png',
#  'test/00019766_038.png',
#  'test/00020333_003.png',
#  'test/00007670_041.png',
#  'test/00004342_007.png',
#  'test/00004931_020.png',
#  'test/00011136_005.png',
#  'test/00000211_007.png',
#  'test/00025368_023.png',
#  'test/00003948_002.png',
#  'test/00028974_005.png',
#  'test/00007586_000.png',
#  'test/00022416_043.png',
#  'test/00003149_007.png',
#  'test/00003064_016.png',
#  'test/00020333_002.png',
#  'test/00004625_004.png',
#  'test/00019018_025.png',
#  'test/00014125_000.png',
#  'test/00006836_000.png',
#  'test/00028722_001.png',
#  'test/00007046_014.png',
#  'test/00019018_030.png',
#  'test/00009218_033.png',
#  'test/00023162_000.png',
#  'test/00004968_004.png',
#  'test/00008522_001.png',
#  'test/00012094_057.png',
#  'test/00007735_002.png',
#  'test/00009437_000.png',
#  'test/00028265_006.png',
#  'test/00021782_027.png',
#  'test/00021181_000.png',
#  'test/00027782_008.png',
#  'test/00014626_020.png',
#  'test/00012834_051.png',
#  'test/00018865_026.png',
#  'test/00016291_030.png',
#  'test/00021374_004.png',
#  'test/00009431_000.png',
#  'test/00020438_008.png',
#  'test/00013380_004.png',
#  'test/00005681_000.png',
#  'test/00027213_011.png',
#  'test/00012834_060.png',
#  'test/00028774_045.png',
#  'test/00019124_096.png',
#  'test/00018840_025.png',
#  'test/00010007_100.png',
#  'test/00000181_057.png',
#  'test/00023065_020.png',
#  'test/00029189_000.png',
#  'test/00029075_006.png',
#  'test/00017544_003.png',
#  'test/00026971_010.png',
#  'test/00005567_008.png',
#  'test/00001373_044.png',
#  'test/00022611_009.png',
#  'test/00011460_059.png',
#  'test/00016568_054.png',
#  'test/00006271_099.png',
#  'test/00018366_041.png',
#  'test/00007728_007.png',
#  'test/00023176_010.png',
#  'test/00015895_027.png',
#  'test/00028576_001.png',
#  'test/00026098_025.png',
#  'test/00001517_001.png',
#  'test/00011683_047.png',
#  'test/00028425_002.png',
#  'test/00020213_019.png',
#  'test/00013911_013.png',
#  'test/00028569_000.png',
#  'test/00013670_167.png',
#  'test/00025252_024.png',
#  'test/00009845_026.png',
#  'test/00004461_014.png',
#  'test/00016184_025.png',
#  'test/00025664_013.png',
#  'test/00014177_000.png',
#  'test/00014956_003.png',
#  'test/00028500_000.png',
#  'test/00010677_024.png',
#  'test/00012609_000.png',
#  'test/00017098_007.png',
#  'test/00017606_024.png',
#  'test/00010828_051.png',
#  'test/00013615_054.png',
#  'test/00003028_060.png',
#  'test/00016191_009.png',
#  'test/00014888_009.png',
#  'test/00008911_023.png',
#  'test/00012021_029.png',
#  'test/00000246_004.png',
#  'test/00006304_007.png',
#  'test/00016508_042.png',
#  'test/00000377_004.png',
#  'test/00004911_015.png',
#  'test/00011460_063.png',
#  'test/00011237_072.png',
#  'test/00028926_001.png',
#  'test/00007676_003.png',
#  'test/00006836_011.png',
#  'test/00025228_001.png',
#  'test/00014839_023.png',
#  'test/00020671_016.png',
#  'test/00004858_054.png',
#  'test/00007018_009.png',
#  'test/00009239_012.png',
#  'test/00029060_000.png',
#  'test/00030258_000.png',
#  'test/00009863_056.png',
#  'test/00000583_061.png',
#  'test/00001836_103.png',
#  'test/00020482_023.png',
#  'test/00030287_002.png',
#  'test/00023168_009.png',
#  'test/00028157_000.png',
#  'test/00028325_000.png',
#  'test/00012294_015.png',
#  'test/00027213_073.png',
#  'test/00000211_014.png',
#  'test/00023156_020.png',
#  'test/00021420_006.png',
#  'test/00019892_010.png',
#  'test/00030394_003.png',
#  'test/00009349_006.png',
#  'test/00020213_106.png',
#  'test/00014203_018.png',
#  'test/00021201_016.png',
#  'test/00020857_006.png',
#  'test/00010936_011.png',
#  'test/00001836_071.png',
#  'test/00026555_002.png',
#  'test/00018840_011.png',
#  'test/00022369_001.png',
#  'test/00013520_010.png',
#  'test/00021201_001.png',
#  'test/00028181_000.png',
#  'test/00017524_034.png',
#  'test/00029105_013.png',
#  'test/00025252_003.png',
#  'test/00025962_000.png',
#  'test/00012622_029.png',
#  'test/00020673_055.png',
#  'test/00008554_013.png',
#  'test/00005066_050.png',
#  'test/00012829_005.png',
#  'test/00017098_004.png',
#  'test/00004461_009.png',
#  'test/00010610_002.png',
#  'test/00026194_010.png',
#  'test/00004822_036.png',
#  'test/00010478_007.png',
#  'test/00007034_022.png',
#  'test/00021711_010.png',
#  'test/00010007_023.png',
#  'test/00013993_133.png',
#  'test/00014203_041.png',
#  'test/00001836_016.png',
#  'test/00016490_018.png',
#  'test/00016607_044.png',
#  'test/00029663_010.png',
#  'test/00007018_022.png',
#  'test/00002868_005.png',
#  'test/00026769_009.png',
#  'test/00013615_065.png',
#  'test/00021463_004.png',
#  'test/00017138_114.png',
#  'test/00011237_064.png',
#  'test/00018253_030.png',
#  'test/00030375_004.png',
#  'test/00004911_021.png',
#  'test/00012364_007.png',
#  'test/00015530_157.png',
#  'test/00013993_122.png',
#  'test/00008522_049.png',
#  'test/00011702_030.png',
#  'test/00021277_022.png',
#  'test/00025252_071.png',
#  'test/00002300_002.png',
#  'test/00020945_026.png',
#  'test/00009863_055.png',
#  'test/00004858_088.png',
#  'test/00006948_005.png',
#  'test/00005801_012.png',
#  'test/00002856_014.png',
#  'test/00020603_001.png',
#  'test/00022192_029.png',
#  'test/00008399_007.png',
#  'test/00029940_001.png',
#  'test/00021703_001.png',
#  'test/00017514_007.png',
#  'test/00022707_000.png',
#  'test/00010007_175.png',
#  'test/00004858_059.png',
#  'test/00004858_032.png',
#  'test/00029075_013.png',
#  'test/00028509_037.png',
#  'test/00013615_060.png',
#  'test/00019919_001.png',
#  'test/00018615_022.png',
#  'test/00028675_000.png',
#  'test/00012386_005.png',
#  'test/00010007_026.png',
#  'test/00019018_016.png',
#  'test/00016414_000.png',
#  'test/00004943_000.png',
#  'test/00014996_006.png',
#  'test/00030608_000.png',
#  'test/00027542_010.png',
#  'test/00020945_019.png',
#  'test/00002300_044.png',
#  'test/00012021_053.png',
#  'test/00020499_009.png',
#  'test/00018233_021.png',
#  'test/00019742_010.png',
#  'test/00009892_013.png',
#  'test/00014387_012.png',
#  'test/00012364_036.png',
#  'test/00022815_035.png',
#  'test/00005986_014.png',
#  'test/00030323_050.png',
#  'test/00014839_008.png',
#  'test/00022726_007.png',
#  'test/00013884_001.png',
#  'test/00022572_019.png',
#  'test/00011237_114.png',
#  'test/00029686_000.png',
#  'test/00017972_004.png',
#  'test/00026098_018.png',
#  'test/00018253_051.png',
#  'test/00028608_001.png',
#  'test/00005612_008.png',
#  'test/00000467_011.png',
#  'test/00008522_050.png',
#  'test/00016732_031.png',
#  'test/00002533_004.png',
#  'test/00013531_023.png',
#  'test/00014203_060.png',
#  'test/00018055_039.png',
#  'test/00015732_011.png',
#  'test/00016732_028.png',
#  'test/00025529_014.png',
#  'test/00025529_016.png',
#  'test/00001248_023.png',
#  'test/00007018_018.png',
#  'test/00019058_000.png',
#  'test/00017098_012.png',
#  'test/00014253_000.png',
#  'test/00029813_016.png',
#  'test/00025954_033.png',
#  'test/00027782_002.png',
#  'test/00010936_007.png',
#  'test/00011355_032.png',
#  'test/00004911_003.png',
#  'test/00014346_007.png',
#  'test/00025612_001.png',
#  'test/00016568_006.png',
#  'test/00026451_032.png',
#  'test/00019124_014.png',
#  'test/00022993_001.png',
#  'test/00014203_000.png',
#  'test/00001946_019.png',
#  'test/00030111_016.png',
#  'test/00020564_001.png',
#  'test/00029813_031.png',
#  'test/00000246_008.png',
#  'test/00013648_003.png',
#  'test/00011953_003.png',
#  'test/00008008_005.png',
#  'test/00000181_063.png',
#  'test/00017138_100.png',
#  'test/00010625_009.png',
#  'test/00009608_042.png',
#  'test/00022572_058.png',
#  'test/00019124_117.png',
#  'test/00017138_039.png',
#  'test/00012609_005.png',
#  'test/00004808_020.png',
#  'test/00030279_006.png',
#  'test/00004832_007.png',
#  'test/00028844_025.png',
#  'test/00012298_006.png',
#  'test/00008911_018.png',
#  'test/00028317_014.png',
#  'test/00005266_000.png',
#  'test/00013176_002.png',
#  'test/00029361_000.png',
#  'test/00009107_003.png',
#  'test/00010575_002.png',
#  'test/00016064_018.png',
#  'test/00029817_003.png',
#  'test/00015255_001.png',
#  'test/00017081_003.png',
#  'test/00009574_016.png',
#  'test/00011857_010.png',
#  'test/00018615_016.png',
#  'test/00016568_037.png',
#  'test/00006329_014.png',
#  'test/00005712_012.png',
#  'test/00012364_062.png',
#  'test/00012747_001.png',
#  'test/00029548_000.png',
#  'test/00013391_003.png',
#  'test/00016429_010.png',
#  'test/00027697_015.png',
#  'test/00014203_047.png',
#  'test/00028844_011.png',
#  'test/00003973_002.png',
#  'test/00011925_030.png',
#  'test/00019187_000.png',
#  'test/00011448_005.png',
#  'test/00001437_007.png',
#  'test/00001582_009.png',
#  'test/00001248_015.png',
#  'test/00021201_095.png',
#  'test/00014663_026.png',
#  'test/00006425_022.png',
#  'test/00026346_002.png',
#  'test/00010447_019.png',
#  'test/00028876_035.png',
#  'test/00013635_003.png',
#  'test/00028403_000.png',
#  'test/00028732_000.png',
#  'test/00020852_002.png',
#  'test/00014398_050.png',
#  'test/00022237_009.png',
#  'test/00018055_011.png',
#  'test/00010775_016.png',
#  'test/00013625_043.png',
#  'test/00011018_001.png',
#  'test/00009229_022.png',
#  'test/00000116_016.png',
#  'test/00005266_001.png',
#  'test/00018860_009.png',
#  'test/00023075_007.png',
#  'test/00007018_019.png',
#  'test/00021201_069.png',
#  'test/00018921_013.png',
#  'test/00019124_022.png',
#  'test/00001373_003.png',
#  'test/00030160_000.png',
#  'test/00001736_029.png',
#  'test/00022416_055.png',
#  'test/00016971_022.png',
#  'test/00029813_009.png',
#  'test/00003062_004.png',
#  'test/00007018_024.png',
#  'test/00014022_021.png',
#  'test/00018366_023.png',
#  'test/00001900_019.png',
#  'test/00025707_011.png',
#  'test/00012045_018.png',
#  'test/00025252_062.png',
#  'test/00029594_004.png',
#  'test/00001836_075.png',
#  'test/00021024_005.png',
#  'test/00017255_002.png',
#  'test/00020213_054.png',
#  'test/00027838_016.png',
#  'test/00013685_009.png',
#  'test/00000181_026.png',
#  'test/00013670_170.png',
#  'test/00012741_013.png',
#  'test/00010775_006.png',
#  'test/00006425_002.png',
#  'test/00011814_028.png',
#  'test/00021481_016.png',
#  'test/00030130_000.png',
#  'test/00017524_013.png',
#  'test/00016522_005.png',
#  'test/00018319_003.png',
#  'test/00013615_045.png',
#  'test/00010007_122.png',
#  'test/00020725_007.png',
#  'test/00012021_002.png',
#  'test/00012048_008.png',
#  'test/00012364_037.png',
#  'test/00012045_000.png',
#  'test/00000181_033.png',
#  'test/00002437_050.png',
#  'test/00010007_149.png',
#  'test/00028138_000.png',
#  'test/00019766_002.png',
#  'test/00029046_000.png',
#  'test/00029404_010.png',
#  'test/00011702_065.png',
#  'test/00014664_005.png',
#  'test/00028174_000.png',
#  'test/00009349_003.png',
#  'test/00026194_005.png',
#  'test/00020146_011.png',
#  'test/00017138_097.png',
#  'test/00018496_009.png',
#  'test/00014251_009.png',
#  'test/00022815_005.png',
#  'test/00030262_000.png',
#  'test/00010568_003.png',
#  'test/00019157_004.png',
#  'test/00026886_011.png',
#  'test/00006271_023.png',
#  'test/00000013_019.png',
#  'test/00029975_000.png',
#  'test/00026562_006.png',
#  'test/00005567_005.png',
#  'test/00008008_020.png',
#  'test/00018055_052.png',
#  'test/00010770_000.png',
#  'test/00029988_000.png',
#  'test/00008008_064.png',
#  'test/00022899_025.png',
#  'test/00021670_004.png',
#  'test/00008399_000.png',
#  'test/00011985_004.png',
#  'test/00023283_014.png',
#  'test/00018657_010.png',
#  'test/00006304_055.png',
#  'test/00006713_003.png',
#  'test/00017151_011.png',
#  'test/00030375_002.png',
#  'test/00018366_006.png',
#  'test/00011460_033.png',
#  'test/00010071_006.png',
#  'test/00016508_060.png',
#  'test/00021381_029.png',
#  'test/00018921_022.png',
#  'test/00011583_009.png',
#  'test/00003029_020.png',
#  'test/00012021_016.png',
#  'test/00011579_023.png',
#  'test/00026886_000.png',
#  'test/00029596_017.png',
#  'test/00007034_023.png',
#  'test/00004342_034.png',
#  'test/00013993_117.png',
#  'test/00025520_001.png',
#  'test/00020945_015.png',
#  'test/00027875_000.png',
#  'test/00015078_014.png',
#  'test/00017403_009.png',
#  'test/00020482_006.png',
#  'test/00022290_020.png',
#  'test/00028974_022.png',
#  'test/00028509_032.png',
#  'test/00007728_003.png',
#  'test/00006271_038.png',
#  'test/00016990_006.png',
#  'test/00018253_040.png',
#  'test/00028733_000.png',
#  'test/00011953_005.png',
#  'test/00017747_008.png',
#  'test/00018360_025.png',
#  'test/00020819_001.png',
#  'test/00007670_019.png',
#  'test/00010828_018.png',
#  'test/00009403_003.png',
#  'test/00001170_015.png',
#  'test/00014022_085.png',
#  'test/00016429_003.png',
#  'test/00000468_031.png',
#  'test/00012622_015.png',
#  'test/00009138_042.png',
#  'test/00009342_006.png',
#  'test/00015563_015.png',
#  'test/00014731_017.png',
#  'test/00028838_001.png',
#  'test/00019271_067.png',
#  'test/00016184_042.png',
#  'test/00010092_043.png',
#  'test/00014447_004.png',
#  'test/00005089_048.png',
#  'test/00013685_047.png',
#  'test/00014626_021.png',
#  'test/00013992_013.png',
#  'test/00017083_001.png',
#  'test/00013625_028.png',
#  'test/00028376_004.png',
#  'test/00011237_025.png',
#  'test/00001787_003.png',
#  'test/00010447_012.png',
#  'test/00018762_002.png',
#  'test/00017500_001.png',
#  'test/00017747_058.png',
#  'test/00028844_016.png',
#  'test/00009845_043.png',
#  'test/00019271_049.png',
#  'test/00020725_023.png',
#  'test/00026263_003.png',
#  'test/00028827_001.png',
#  'test/00002856_021.png',
#  'test/00015646_007.png',
#  'test/00027089_001.png',
#  'test/00001673_001.png',
#  'test/00018249_008.png',
#  'test/00023093_006.png',
#  'test/00017747_050.png',
#  'test/00028285_006.png',
#  'test/00014798_019.png',
#  'test/00004893_041.png',
#  'test/00020671_001.png',
#  'test/00019275_005.png',
#  'test/00021700_000.png',
#  'test/00015770_012.png',
#  'test/00018721_000.png',
#  'test/00029089_000.png',
#  'test/00012376_012.png',
#  'test/00020213_014.png',
#  'test/00012413_021.png',
#  'test/00030427_002.png',
#  'test/00030408_009.png',
#  'test/00018055_025.png',
#  'test/00014956_011.png',
#  'test/00013884_002.png',
#  'test/00012094_009.png',
#  'test/00013670_070.png',
#  'test/00014203_057.png',
#  'test/00015605_048.png',
#  'test/00028208_015.png',
#  'test/00005712_018.png',
#  'test/00017236_078.png',
#  'test/00017972_012.png',
#  'test/00007886_009.png',
#  'test/00002350_006.png',
#  'test/00015442_021.png',
#  'test/00002350_012.png',
#  'test/00010936_003.png',
#  'test/00021710_000.png',
#  'test/00001437_050.png',
#  'test/00005681_025.png',
#  'test/00000506_024.png',
#  'test/00021303_007.png',
#  'test/00014022_083.png',
#  'test/00028526_017.png',
#  'test/00013670_033.png',
#  'test/00013346_023.png',
#  'test/00022877_013.png',
#  'test/00023116_017.png',
#  'test/00027357_003.png',
#  'test/00014197_005.png',
#  'test/00017318_005.png',
#  'test/00019637_009.png',
#  'test/00003089_002.png',
#  'test/00009811_000.png',
#  'test/00015953_013.png',
#  'test/00025954_035.png',
#  'test/00005681_052.png',
#  'test/00016064_001.png',
#  'test/00004832_023.png',
#  'test/00000583_017.png',
#  'test/00009507_016.png',
#  'test/00005567_020.png',
#  'test/00007034_082.png',
#  'test/00021495_001.png',
#  'test/00013531_022.png',
#  'test/00009237_023.png',
#  'test/00016175_006.png',
#  'test/00023325_015.png',
#  'test/00000211_002.png',
#  'test/00011702_017.png',
#  'test/00008008_055.png',
#  'test/00011579_007.png',
#  'test/00030213_000.png',
#  'test/00013128_003.png',
#  'test/00011136_015.png',
#  'test/00010007_104.png',
#  ...]

# %%
size = 0; 
for i in data.test_ds.fnames: 
    img_name = i.replace("test/", "")
    el = df.loc[df['Image Index'] == img_name]
    if el.empty: 
        print()
    else: 
        size = size+1
        y_value = el['searching_disease'].values[0]

# %%
size

# %%
el = df.loc[df['Image Index'] == "111.png"]

# %%
el.empty
# Out:
# True

# %%
denne = el['searching_disease'].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-e6a4157a7c8b> in <module>()
# ----> 1 denne = el['searching_disease'].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
denne
# Out:
# False

# %% [markdown]
# # Training

# %%
learn = ConvLearner.pretrained(arch, data, opt_fn=optim.Adam, ps=0.5)

# %%
learn.lr_find()

# %%
learn.sched.plot()

# %%
lr = 0.0001

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)

# %%
learn.lr_find()
learn.sched.plot()

# %%
learn.unfreeze()

# %%
lrs = [lr/9, lr/3,lr];

# %%
learn.fit(lrs, 1, cycle_len=1)

# %%
learn.save(f'{sz}169{disease_name}')

# %%
sz=128
learn.set_data(get_data(sz))
learn.freeze()

# %%
#learn.lr_find()
#learn.sched.plot()

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)

# %%
learn.unfreeze()

# %%
learn.fit(lrs, 1, cycle_len=1)  #sette epoch verdi ned til 2 kanskje

# %%
learn.save(f'{sz}169{disease_name}')

# %%
#sz = 128
#learn.load(f'{sz}169{disease_name}')

# %%
sz = 259

# %%
learn.set_data(get_data(sz))
learn.freeze()
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
#overfitter veldig når jeg kjører unfreeze

# %%
learn.unfreeze()

# %%
learn.fit(lrs, 1, cycle_len=1)

# %%
learn.save(f'{sz}169{disease_name}')

# %%
learn.sched.plot_loss()

# %% [markdown]
# #  Analyzing the results

# %%
log_preds,y = learn.TTA()
probs = np.mean(np.exp(log_preds),axis=0)
accuracy = accuracy_np(probs, y)

# %%
print('Accuracy with TTA: '+str(accuracy))

# %%
probs

# %%
preds = np.argmax(probs, axis=1)  #selects the position of the highest value
#probs = probs[:,1]

# %%
cm = confusion_matrix(y,preds);

# %%
plot_confusion_matrix(cm, ['Others', disease_name])

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y, preds)

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[val_idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, val_idx): return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(val_idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in val_idxs]
    title_probs = [probs[x] for x in val_idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect effusion")

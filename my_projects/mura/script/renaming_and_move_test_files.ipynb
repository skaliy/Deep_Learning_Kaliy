# %%
import os

# %%
XR= 'XR_WRIST'

# %%
PATH = f'/home/sathiesh/Deep_Learning_Kaliy/my_projects/mura/data/MURA-v1.0/test_copy/{XR}/'

# %%
folders = os.listdir(PATH) #alle pasientene innefor et felt

# %%
folders
# Out:
# ['patient12217',
#  'patient12213',
#  'patient12200',
#  'patient12214',
#  'patient12206',
#  'patient12195',
#  'patient12198',
#  'patient12197',
#  'patient12211',
#  'patient12222',
#  'patient12196',
#  'patient12221',
#  'patient12202',
#  'patient12212',
#  'patient12215',
#  'patient12208',
#  'patient12205',
#  'patient12209',
#  'patient12203',
#  'patient12199',
#  'patient12210',
#  'patient12194',
#  'patient12201',
#  'patient12218',
#  'patient12220',
#  'patient12219',
#  'patient12204',
#  'patient12207',
#  'patient12216']

# %%
for file in folders:
    print('\n')
    patient_folder = f'{PATH}{file}/' 
    patient_studies = os.listdir(patient_folder) #alle pasientene 
    
    for study in patient_studies:  #alle studiene til en pasient (1-2 studier)
        study_folder = f'{patient_folder}{study}/'
        study_images = os.listdir(study_folder)
        
        for image in study_images: 
            var = XR+'_'+file+'_'+study+'_'+ image #patient12104_study1_image3.png
            print(var)
            old_file = os.path.join(study_folder, image)
            new_file = os.path.join('/home/sathiesh/Deep_Learning_Kaliy/my_projects/mura/data/test', var)
            os.rename(old_file, new_file)
# Out:
# XR_WRIST_patient12217_study1_image3.png
# XR_WRIST_patient12217_study1_image1.png
# XR_WRIST_patient12217_study1_image2.png
#
#
# XR_WRIST_patient12213_study1_image3.png
# XR_WRIST_patient12213_study1_image1.png
# XR_WRIST_patient12213_study1_image2.png
#
#
# XR_WRIST_patient12200_study1_image1.png
#
#
# XR_WRIST_patient12214_study1_image1.png
# XR_WRIST_patient12214_study1_image2.png
#
#
# XR_WRIST_patient12206_study1_image3.png
# XR_WRIST_patient12206_study1_image1.png
# XR_WRIST_patient12206_study1_image2.png
#
#
# XR_WRIST_patient12195_study1_image1.png
# XR_WRIST_patient12195_study1_image2.png
#
#
# XR_WRIST_patient12198_study1_image3.png
# XR_WRIST_patient12198_study1_image1.png
# XR_WRIST_patient12198_study1_image4.png
# XR_WRIST_patient12198_study1_image2.png
#
#
# XR_WRIST_patient12197_study1_image1.png
# XR_WRIST_patient12197_study1_image2.png
#
#
# XR_WRIST_patient12211_study1_image3.png
# XR_WRIST_patient12211_study1_image1.png
# XR_WRIST_patient12211_study1_image2.png
#
#
# XR_WRIST_patient12222_study1_image3.png
# XR_WRIST_patient12222_study1_image1.png
# XR_WRIST_patient12222_study1_image2.png
#
#
# XR_WRIST_patient12196_study1_image1.png
# XR_WRIST_patient12196_study1_image2.png
#
#
# XR_WRIST_patient12221_study1_image1.png
# XR_WRIST_patient12221_study1_image2.png
#
#
# XR_WRIST_patient12202_study1_image3.png
# XR_WRIST_patient12202_study1_image1.png
# XR_WRIST_patient12202_study1_image2.png
#
#
# XR_WRIST_patient12212_study1_image3.png
# XR_WRIST_patient12212_study1_image1.png
# XR_WRIST_patient12212_study1_image2.png
#
#
# XR_WRIST_patient12215_study1_image3.png
# XR_WRIST_patient12215_study1_image1.png
# XR_WRIST_patient12215_study1_image4.png
# XR_WRIST_patient12215_study1_image2.png
#
#
# XR_WRIST_patient12208_study1_image3.png
# XR_WRIST_patient12208_study1_image1.png
# XR_WRIST_patient12208_study1_image2.png
#
#
# XR_WRIST_patient12205_study1_image1.png
# XR_WRIST_patient12205_study1_image2.png
#
#
# XR_WRIST_patient12209_study1_image3.png
# XR_WRIST_patient12209_study1_image1.png
# XR_WRIST_patient12209_study1_image2.png
#
#
# XR_WRIST_patient12203_study1_image3.png
# XR_WRIST_patient12203_study1_image1.png
# XR_WRIST_patient12203_study1_image2.png
#
#
# XR_WRIST_patient12199_study1_image3.png
# XR_WRIST_patient12199_study1_image1.png
# XR_WRIST_patient12199_study1_image4.png
# XR_WRIST_patient12199_study1_image2.png
#
#
# XR_WRIST_patient12210_study1_image1.png
# XR_WRIST_patient12210_study1_image2.png
#
#
# XR_WRIST_patient12194_study1_image3.png
# XR_WRIST_patient12194_study1_image1.png
# XR_WRIST_patient12194_study1_image2.png
#
#
# XR_WRIST_patient12201_study1_image3.png
# XR_WRIST_patient12201_study1_image1.png
# XR_WRIST_patient12201_study1_image2.png
#
#
# XR_WRIST_patient12218_study1_image3.png
# XR_WRIST_patient12218_study1_image1.png
# XR_WRIST_patient12218_study1_image2.png
#
#
# XR_WRIST_patient12220_study1_image1.png
# XR_WRIST_patient12220_study1_image2.png
#
#
# XR_WRIST_patient12219_study1_image3.png
# XR_WRIST_patient12219_study1_image1.png
# XR_WRIST_patient12219_study1_image2.png
#
#
# XR_WRIST_patient12204_study1_image1.png
# XR_WRIST_patient12204_study1_image2.png
#
#
# XR_WRIST_patient12207_study1_image3.png
# XR_WRIST_patient12207_study1_image1.png
# XR_WRIST_patient12207_study1_image2.png
#
#
# XR_WRIST_patient12216_study1_image3.png
# XR_WRIST_patient12216_study1_image1.png
# XR_WRIST_patient12216_study1_image4.png
# XR_WRIST_patient12216_study1_image2.png

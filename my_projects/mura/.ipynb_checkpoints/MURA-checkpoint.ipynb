# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # MURA

# %%
import sys
sys.path.append("../../fastai/")

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
from sklearn.metrics import confusion_matrix

# %%
PATH = "/home/sathiesh/Deep_Learning_Kaliy/my_projects/mura/data/"  #MMIV
#PATH = "/Users/Sathiesh/MachineLearning/Deep_Learning_Kaliy/my_projects/mura/data/" #Home

# %%
os.listdir(PATH)
# Out:
# ['test_submission_example.csv',
#  'models',
#  'tmp',
#  'MURA-v1.0',
#  'valid.csv',
#  'test',
#  'cleaned_label.csv',
#  'train.csv']

# %%
df_train = pd.read_csv(f'{PATH}train.csv')
df_valid = pd.read_csv(f'{PATH}valid.csv')

# %%
df_train.head()
# Out:
#   MURA-v1.0/train/XR_SHOULDER/patient00001/study1_positive/image1.png  1
# 0  MURA-v1.0/train/XR_SHOULDER/patient00001/study...                   1
# 1  MURA-v1.0/train/XR_SHOULDER/patient00001/study...                   1
# 2  MURA-v1.0/train/XR_SHOULDER/patient00002/study...                   1
# 3  MURA-v1.0/train/XR_SHOULDER/patient00002/study...                   1
# 4  MURA-v1.0/train/XR_SHOULDER/patient00002/study...                   1

# %%
df_train.columns = ['Image Index', 'Abnormality']

# %%
df_valid.columns = ['Image Index', 'Abnormality']

# %%
df_train.shape, df_valid.shape
# Out:
# ((37110, 2), (3224, 2))

# %%
df = pd.concat([df_train, df_valid], ignore_index=True)
df.head()
# Out:
#                                          Image Index  Abnormality
# 0  MURA-v1.0/train/XR_SHOULDER/patient00001/study...            1
# 1  MURA-v1.0/train/XR_SHOULDER/patient00001/study...            1
# 2  MURA-v1.0/train/XR_SHOULDER/patient00002/study...            1
# 3  MURA-v1.0/train/XR_SHOULDER/patient00002/study...            1
# 4  MURA-v1.0/train/XR_SHOULDER/patient00002/study...            1

# %%
df.shape
# Out:
# (40334, 2)

# %%
df['Abnormality'] = df['Abnormality'].astype('bool')

# %%
val_idxs = np.array(range(len(df_train), len(df)))

# %%
cleaned_label_path = f'{PATH}cleaned_label.csv'
df.to_csv(cleaned_label_path, index=False)

# %% [markdown]
# # View data

# %%
sz = 64
arch = dn169
bs = 16

# %%
def get_data(sz): 
    tfms = tfms_from_model(arch, sz, aug_tfms=RandomFlip())  #transforms_side_on
    return ImageClassifierData.from_csv(PATH ,'', cleaned_label_path , test_name='test',
                                       val_idxs=val_idxs, tfms=tfms, bs=bs);

# %%
data = get_data(sz)

# %%
fn = PATH+data.trn_ds.fnames[10]
fn
# Out:
# '/home/sathiesh/Deep_Learning_Kaliy/my_projects/mura/data/MURA-v1.0/train/XR_ELBOW/patient00032/study1_negative/image2.png'

# %%
img = PIL.Image.open(fn);
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x406 at 0x7F0A52675278>

# %%
data.trn_ds.fnames.shape ,data.val_ds.fnames.shape
# Out:
# ((37110,), (3224,))

# %% [markdown]
# # Training

# %%
learn = ConvLearner.pretrained(arch, data, ps = 0.5, opt_fn=optim.Adam)

# %%
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  66%|██████▌   | 1522/2320 [01:24<00:44, 18.11it/s, loss=2.82]
#  66%|██████▌   | 1522/2320 [01:40<00:52, 15.22it/s, loss=2.82]

# %%
lr = 0.00005

# %%
learn.fit(lr,3, cycle_len=1, cycle_mult =2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
#   2%|▏         | 36/2320 [00:02<02:58, 12.81it/s, loss=0.901]
#   2%|▏         | 42/2320 [00:03<02:42, 13.99it/s, loss=0.927]
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/sathiesh/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/sathiesh/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 62, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/sathiesh/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss   accuracy
#     0      0.707434   0.631966   0.648824
#     1      0.678306   0.619872   0.669864
#     2      0.696989   0.606514   0.676361
#     3      0.612926   0.583138   0.696163
#     4      0.620792   0.575291   0.695235
#     5      0.588888   0.577134   0.699567
#     6      0.601143   0.595808   0.681931
# [0.5958081261798887, 0.681930693069307]

# %%
learn.unfreeze()

# %%
lrs = [lr/9, lr/3, lr]

# %%
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.599318   0.591068   0.688119
#     1      0.605938   0.555396   0.715347
#     2      0.526973   0.543369   0.729579
#     3      0.550057   0.52865    0.73948
#     4      0.5136     0.523564   0.747215
#     5      0.508329   0.515999   0.749691
#     6      0.495505   0.507457   0.753713
# [0.5074565452293004, 0.7537128712871287]

# %%
learn.save(f'{sz}')

# %%
sz = 128

# %%
learn.set_data(get_data(sz))
learn.freeze()

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.546065   0.544216   0.724319
#     1      0.5177     0.52048    0.743502
#     2      0.529752   0.53186    0.733911
#     3      0.535724   0.534067   0.732364
#     4      0.523907   0.522981   0.740718
#     5      0.532484   0.52443    0.73948
#     6      0.530461   0.529665   0.736077
# [0.5296645607098495, 0.7360767326732673]

# %%
learn.unfreeze();
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.500054   0.47983    0.775062
#     1      0.50946    0.468324   0.785272
#     2      0.411442   0.45925    0.79177
#     3      0.472313   0.452962   0.806931
#     4      0.422165   0.442452   0.809406
#     5      0.386189   0.456068   0.80724
#     6      0.405715   0.461462   0.804455
# [0.46146219223737717, 0.8044554455445545]

# %%
learn.save(f'{sz}')

# %%
sz = 256

# %%
learn.set_data(get_data(sz))
learn.freeze()

# %%
learn.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.470147   0.484124   0.781559
#     1      0.474486   0.479897   0.780322
#     2      0.445885   0.475637   0.784344
#     3      0.456145   0.462979   0.788366
#     4      0.45158    0.468067   0.7862
#     5      0.447946   0.457487   0.78651
#     6      0.478775   0.463011   0.788366
# [0.4630114951788789, 0.7883663366336634]

# %%
learn.save(f'{sz}')

# %%
learn.unfreeze()
learn.fit(lrs, 3, cycle_len=1, cycle_mult=2)
#Hvis ikke overfitting her: 
#learn.save(f'{sz}')
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.431249   0.431473   0.809406
#     1      0.43432    0.431601   0.808168
#     2      0.39347    0.419832   0.818688
#     3      0.403376   0.436353   0.804765
#     4      0.347866   0.425618   0.814975
#     5      0.345876   0.431581   0.815285
#     6      0.348603   0.436824   0.816213
# [0.4368244184199536, 0.8162128712871287]

# %%
learn.sched.plot_loss()

# %% [markdown]
# # Transfer learning

# %%
sz = 64

# %%
data = get_data(sz)

# %%
learnTL = ConvLearner.pretrained(arch, data, opt_fn=optim.Adam, ps = 0.5)

# %%
learnTL.load('256169denne') #pretrained weights on chestX 14 dataset

# %%
learnTL.lr_find()
learnTL.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  66%|██████▌   | 1528/2320 [00:50<00:26, 30.00it/s, loss=2.61]

# %%
lr = 0.0001

# %%
learnTL.fit(lr,3, cycle_len=1, cycle_mult =2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
#   7%|▋         | 169/2320 [00:06<01:19, 27.22it/s, loss=0.989]
#   7%|▋         | 169/2320 [00:06<01:21, 26.29it/s, loss=0.98]
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/sathiesh/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/sathiesh/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_monitor.py", line 62, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/sathiesh/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# epoch      trn_loss   val_loss   accuracy
#     0      0.656332   0.649789   0.608251
#     1      0.608804   0.62063    0.656948
#     2      0.609648   0.613676   0.672146
#  55%|█████▌    | 1277/2320 [00:42<00:34, 30.28it/s, loss=0.592]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-19b42a929f07> in <module>()
# ----> 1 learnTL.fit(lr,3, cycle_len=1, cycle_mult =2)
#
# ~/Deep_Learning_Kaliy/fastai/fastai/learner.py in fit(self, lrs, n_cycle, wds, **kwargs)
#     285         self.sched = None
#     286         layer_opt = self.get_layer_opt(lrs, wds)
# --> 287         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     288
#     289     def warm_up(self, lr, wds=None):
#
# ~/Deep_Learning_Kaliy/fastai/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, **kwargs)
#     232             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16,
#     233             swa_model=self.swa_model if use_swa else None, swa_start=swa_start,
# --> 234             swa_eval_freq=swa_eval_freq, **kwargs)
#     235
#     236     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/Deep_Learning_Kaliy/fastai/fastai/model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, **kwargs)
#     124         if all_val: val_iter = IterBatch(cur_data.val_dl)
#     125
# --> 126         for (*x,y) in t:
#     127             batch_num += 1
#     128             for cb in callbacks: cb.on_batch_begin()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     895 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     896
# --> 897             for obj in iterable:
#     898                 yield obj
#     899                 # Update and possibly print the progressbar.
#
# ~/Deep_Learning_Kaliy/fastai/fastai/dataloader.py in __iter__(self)
#      86                 # avoid py3.6 issue where queue is infinite and can result in memory exhaustion
#      87                 for c in chunk_iter(iter(self.batch_sampler), self.num_workers*10):
# ---> 88                     for batch in e.map(self.get_batch, c):
#      89                         yield get_tensor(batch, self.pin_memory, self.half)
#      90
#
# ~/anaconda3/envs/fastai/lib/python3.6/concurrent/futures/_base.py in result_iterator()
#     584                     # Careful not to keep a reference to the popped future
#     585                     if timeout is None:
# --> 586                         yield fs.pop().result()
#     587                     else:
#     588                         yield fs.pop().result(end_time - time.time())
#
# ~/anaconda3/envs/fastai/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/envs/fastai/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
learnTL.lr_find()
learnTL.sched.plot()

# %%
lrs = [1e-6,1e-5,1e-4]
learnTL.unfreeze()

# %%
learnTL.fit(lrs, 3, cycle_len=1, cycle_mult=2)

# %%
learnTL.save(f'{sz}TL')

# %%
sz = 128

# %%
learnTL.set_data(get_data(sz))
learnTL.freeze()

# %%
learnTL.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.518731   0.525419   0.742574
#     1      0.502761   0.520927   0.749381
#     2      0.498266   0.512335   0.753094
#     3      0.477254   0.510966   0.753094
#     4      0.514261   0.511527   0.754022
#     5      0.51211    0.514714   0.753094
#     6      0.502933   0.517098   0.754641
# [0.5170981363199725, 0.7546410891089109]

# %%
learnTL.unfreeze()
learnTL.fit(lrs, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.452513   0.45548    0.797649
#     1      0.480903   0.476043   0.787438
#     2      0.460333   0.441745   0.80724
#     3      0.458303   0.466347   0.787748
#     4      0.434499   0.455211   0.794245
#     5      0.396327   0.441331   0.80724
#     6      0.40081    0.439938   0.8125
# [0.4399375283887776, 0.8125]

# %%
learnTL.save(f'{sz}TL')

# %%
sz = 256

# %%
learnTL.set_data(get_data(sz))
learnTL.freeze()

# %%
learnTL.fit(lr, 3, cycle_len=1, cycle_mult=2)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.478999   0.491053   0.778156
#     1      0.480138   0.484113   0.778775
#     2      0.449594   0.494191   0.771658
#     3      0.499164   0.478745   0.784344
#     4      0.492675   0.479841   0.784344
#     5      0.454798   0.48084    0.784035
#     6      0.456476   0.473894   0.785582
# [0.47389351340508695, 0.7855816831683168]

# %%
learnTL.save(f'{sz}TL')

# %%
learnTL.unfreeze()
learnTL.fit(lrs,3, cycle_len=1, cycle_mult=2)
#learnTL.save(f'{sz}TL') hvis den ikke overfitter
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=7), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.43651    0.432019   0.8125
#     1      0.439326   0.431795   0.808787
#     2      0.412185   0.417971   0.818069
#     3      0.446584   0.451304   0.80198
#     4      0.430433   0.425173   0.815285
#     5      0.396665   0.418967   0.822092
#     6      0.384459   0.411816   0.82302
# [0.41181570380040916, 0.823019801980198]

# %%
learnTL.sched.plot_loss()

# %% [markdown]
# # Prediction on test set

# %%
test_list = data.test_ds.fnames
len(test_list)
# Out:
# 559

# %%
#fjerne imagex.png fra stringen, så man kan finne alle bildene for et studie
def searching_string(pasient_image_path):
    string_size = len(pasient_image_path) - len('_image1.png')
    return pasient_image_path[:string_size]

# %%
#finne indeksene til bildene som er med i studiet
def find_img_indxs(pasient_study): 
    return [test_list.index(i) for i in test_list if pasient_study in i]

# %%
trn_tfms, val_tfms = tfms_from_model(arch, sz) # get transformations
def predict_abnormality(fn): 
    im = open_image(fn)
    im_val = val_tfms(im)
    preds = learnTL.predict_array(im_val[None])
    return np.argmax(preds)

# %% [markdown]
# you should use the 2nd return val from tfms_from_model. The first one includes data augmentation, e.g. for the training set. For predictions you don’t want that, so use the 2nd one.
# Jeremy

# %%
#fjerne indeksene til bildene fra test_list når man er ferdig med å predikere et studie. 
def del_indxs(study_img_indxs):
    #for i in study_img_indxs: 
       # del test_list[i] 
    return np.delete(test_list, study_img_indxs).tolist()

# %%
predictions_dict = {}

while(len(test_list)>0): 
    string_study = searching_string(test_list[0])
    study_img_indxs = find_img_indxs(string_study)
    
    prediction_list = [] #skal inneholde alle predikasjonene for et studie

    #Her skal det predikeres på hvert av bildene i studiet
    for i in study_img_indxs: 
        prediction = predict_abnormality(PATH+test_list[i])
        prediction_list.append(prediction)
        
    predictions_dict[string_study] = max(prediction_list) # nøkkel : navnet til studiet + value: predikasjonen (hvis en av de er True, så er studiet True)
    
    #ferdig med predikasjon for et studie
    test_list = del_indxs(study_img_indxs)
    #print(find_img_indxs(string_study)) #bare for å teste at alle listene som retuneres er tomme

# %%
len(predictions_dict)
# Out:
# 209

# %%
df_test = pd.read_csv(f'{PATH}test_submission_example.csv', header=None)

# %%
df_test.shape
# Out:
# (209, 2)

# %%
df_test.columns = ['Study','Abnormality']

# %%
df_test.head()
# Out:
#                                   Study  Abnormality
# 0  test/XR/FOREARM/patient12044/study1/            1
# 1  test/XR/FOREARM/patient12045/study1/            0
# 2  test/XR/FOREARM/patient12046/study1/            1
# 3  test/XR/FOREARM/patient12047/study1/            0
# 4  test/XR/FOREARM/patient12048/study1/            1

# %%
y = []
preds = []

# %%
def add_values(y_value, preds_value): 
    y.append(y_value)
    preds.append(preds_value)

# %%
def test_accuracy(pred_dict, df_test): 
    num_correct = 0; 
    for key, value in pred_dict.items(): 
        searching_string = key.replace('_', '/')+'/' #for å matche verdiene i df
        row = df_test.loc[df_test['Study'] == searching_string]
        
        if(int(row.Abnormality.values) == value): 
            num_correct+=1
        
        add_values(int(row.Abnormality.values), value)
        
    return num_correct/len(pred_dict)

# %%
test_accuracy(predictions_dict, df_test)
# Out:
# 0.583732057416268

# %%
cm = confusion_matrix(y,preds);

# %%
plot_confusion_matrix(cm, "data.classes")
# Out:
# [[50 39]
#  [48 72]]
